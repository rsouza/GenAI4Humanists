# %%
# !pip install -q llama-index
# !pip install -q streamlit

# %%
import os
import sys
import subprocess

# !streamlit run ./10-Chatbot_LLamaIndex_Streamlit_backend.py \
--server.enableCORS=False \
--server.enableXsrfProtection=False \
--browser.gatherUsageStats=False
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.10.1.21:8501
#
# Querying with: Who is Paul Graham?
# Querying with: What is the name of his first company?
# Querying with: What is the size of an atom?
# ^C
#   Stopping...
